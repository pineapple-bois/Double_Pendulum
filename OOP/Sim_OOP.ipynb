# %% [markdown]
# # Double Pendulum Simulation OOP
#
# ## Two models: `simple` & `compound`

# %%
import sympy as sp
from Class_OOP import DoublePendulum

# %% [markdown]
# ----
# &nbsp;
# #### Set unity parameters for masses such that,
#
# $$m_1=m_2=M_1=M_2=1\text{kg}$$
#
# $$l_1=l_2=1\text{m}$$

# %%
M1, M2, m1, m2, l1, l2, g = sp.symbols("M1, M2, m1, m2, l1, l2, g", positive=True, real=True)

# Define parameters
params = {
    m1: 1,     # mass bob1
    m2: 1,     # mass bob2
    l1: 1,     # length1
    l2: 1,     # length2
    M1: 1,     # mass rod1
    M2: 1,     # mass rod2
    g : 9.81   # acceleration due to gravity
}

# %% [markdown]
# ----
# &nbsp;
# ## Double Pendulums
#
# - The `init_values` array specifies the starting angles and angular velocities of the two pendulum arms in degrees.
# - The `time` array defines the simulation's start and end times and the number of points to compute `[start, end, points]`

# %%
# Change all Pendulums in notebook
model = 'compound' # or compound or simple

# %% [markdown]
# ----
# &nbsp;
# ### Pendulum 1, $\theta_2 = 45 \degree$

# %%
init_values = [0, 45, 0, 0]
time = [0, 20, 4000]

# %%
pendulum1 = DoublePendulum(parameters=params, initial_conditions=init_values, 
                           time_vector=time, model=model)
pendulum1.time_graph()
pendulum1.phase_path()

# %%
pendulum1.precompute_positions()  # Precompute before the animation
fig = pendulum1.animate_pendulum(trace=True, appearance='dark')
#fig.show()

# %% [markdown]
# ![img](Figures/Pendulum1.png)

# %% [markdown]
# ### Pendulum 2, $\theta_1 = 30 \degree$, $\theta_2 = 45 \degree$

# %%
init_values = [30, 45, 0, 0]
time = [0, 20, 4000]
pendulum2 = DoublePendulum(parameters=params, initial_conditions=init_values, time_vector=time, model=model)
pendulum2.time_graph()
pendulum2.phase_path()

# %%
pendulum2.precompute_positions()  # Precompute before the animation
fig = pendulum2.animate_pendulum(trace=True, appearance='dark')
#fig.show()

# %% [markdown]
# ![img](Figures/Pendulum2.png)

# %% [markdown]
# ----
# &nbsp;
# ## Chaotic Motion

# %% [markdown]
# ### Pendulum 3, $\theta_1 = -105 \degree$, $\theta_2 = 105 \degree$
#
# (Chaotic motion for both models)

# %%
init_values = [-105, 105, 0, 0]
time = [0, 20, 4000]
pendulum3 = DoublePendulum(parameters=params, initial_conditions=init_values, time_vector=time, model=model)
pendulum3.time_graph()
pendulum3.phase_path()

# %%
pendulum3.precompute_positions()  # Precompute before the animation
fig = pendulum3.animate_pendulum(trace=True, appearance='dark')
#fig.show()

# %% [markdown]
# ![img](Figures/Pendulum3.png)

# %% [markdown]
# ----
# &nbsp;
# ## From Chaotic to Quasi-periodic

# %% [markdown]
# ### Pendulum 4, $\theta_1 = 60 \degree$, $\theta_2 = 100 \degree$
#
# (Chaotic motion for the compound model - both initial conditions)

# %%
init_values = [60, 100, 0, 0]
time = [0, 20, 4000]
pendulum4 = DoublePendulum(parameters=params, initial_conditions=init_values, time_vector=time, model=model)
pendulum4.time_graph()
pendulum4.phase_path()

# %%
pendulum4.precompute_positions()  # Precompute before the animation
fig = pendulum4.animate_pendulum(trace=True, appearance='dark')
#fig.show()

# %% [markdown]
# ![img](Figures/Pendulum4.png)

# %% [markdown]
# $1 \degree$ difference from above pendulum

# %% [markdown]
# ### Pendulum 5, $\theta_1 = 61 \degree$, $\theta_2 = 100 \degree$

# %%
init_values = [61, 100, 0, 0]
time = [0, 20, 4000]

pendulum5 = DoublePendulum(parameters=params, initial_conditions=init_values, time_vector=time, model=model)
pendulum5.time_graph()
pendulum5.phase_path()

# %%
pendulum5.precompute_positions()  # Precompute before the animation
fig = pendulum5.animate_pendulum(trace=True, appearance='dark')
#fig.show()

# %% [markdown]
# ![img](Figures/Pendulum5.png)

# %% [markdown]
# ----
# &nbsp;
# ## Interesting Normal Mode
# $\theta_2 = 120 \degree$

# %%
init_values = [0, 120, 0, 0]
time = [0, 20, 4000]
pendulum5 = DoublePendulum(parameters=params, initial_conditions=init_values, time_vector=time, model=model)
pendulum5.time_graph()
pendulum5.phase_path()

# %%
pendulum5.precompute_positions()  # Precompute before the animation
fig = pendulum5.animate_pendulum(trace=True, appearance='dark')
#fig.show()

# %% [markdown]
# ![img](Figures/Pendulum6.png)

# %% [markdown]
# ----
